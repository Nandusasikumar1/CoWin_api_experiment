# %%
import pandas as pd
import numpy as np 
import requests
import streamlit as st
class cowin():
    def read(self):
        file1=pd.DataFrame({'district_id':[295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308],
                          'districts':['Kasaragod','Thiruvananthapuram','Kannur','Kollam','Wayanad','Pathanamthitta','Alappuzha','Malappuram','Thrissur','Kottayam','Kozhikode','Idukki','Ernakulam','Palakkad']
                          })
        return file1
    def cowin_data(self):
        file=self.read()
        date=st.text_input('Enter date(mm-dd-yyyy)',value='01-06-2021',key=2)
        districts=st.selectbox('Select District',list(file['districts']))
        dist_id=list(file[file['districts']==districts]['district_id'])[0]
        response=requests.get('https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByDistrict?',params={'district_id':str(dist_id),'date':date})
        return response
        c=[]
        for i in response.json():
            for k in response.json()[i]:
                c.append(k)
        keyss=[i.keys() for i in c]
        keys1=list(np.unique(keyss)[0])
        index=[keys1.index(i) for i in ['name','pincode','fee_type','min_age_limit','vaccine','available_capacity_dose1','available_capacity_dose2']]
        data={}
        for f in index:
            data[keys1[f]]=[]
            for p in c:
                data[keys1[f]].append(list(p.values())[f])
        return data

    def show(self):
        st.set_page_config(page_title="Nandu's CoWin api experiment")
        hide_streamlit_style = """
        <style>
        #MainMenu {visibility: hidden;}
        footer {visibility: hidden;}
        </style>
        """
        df=pd.DataFrame(self.cowin_data())
        st.markdown(hide_streamlit_style, unsafe_allow_html=True)
        st.dataframe(df)
if __name__=='__main__':
    cowin().show()

# %%
st.set_page_config(page_title="Nandu's CoWin api experiment")

hide_streamlit_style = """
<style>
#MainMenu {visibility: hidden;}
footer {visibility: hidden;}
</style>
"""
st.markdown(hide_streamlit_style, unsafe_allow_html=True)
st.title('Vaccination Center Finder')
st.title('Vaccination Centers')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
res=requests.get('https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByDistrict?',params={'district_id':'297','date':'01-06-2021'})

# %%
res.json()
# Out:
# {'sessions': [{'center_id': 604294,
#    'name': 'Kuthuparamba Taluk Hospital',
#    'address': 'Kuthuparamba Municipal Stadium(Kuthuparamba TH)',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Chittariparamba',
#    'pincode': 670643,
#    'from': '11:30:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': 'bb7c8167-279c-4984-a68b-bffd12558919',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['11:30AM-01:30PM', '01:30PM-03:00PM']},
#   {'center_id': 115419,
#    'name': 'Chittariparamba PHC',
#    'address': 'PHC Chittariparamba',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Chittariparamba',
#    'pincode': 670650,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': 'fac875a3-60f6-42c1-ab7f-c1eff28bbb87',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115189,
#    'name': 'Koottumugham CHC',
#    'address': 'Koottumugham CHC Koottumugham Koottumugham(P O)',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Mayyil',
#    'pincode': 670631,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '2828116e-58c6-40bb-b8b7-b7e96109b9ee',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604195,
#    'name': 'District Hospital Kannur',
#    'address': 'Ayikkara Government Hospital Road',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Azhikode',
#    'pincode': 670017,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '73c651ab-1b41-4261-920d-b495df17fe2b',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604405,
#    'name': 'Alakode (T) FHC',
#    'address': 'FHC Therthalli',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Oduvallithattu',
#    'pincode': 670571,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 0,
#    'long': 0,
#    'fee_type': 'Free',
#    'session_id': 'ce74a2d1-d8b1-402f-91ff-99e761d1c6ac',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 115439,
#    'name': 'Pattiam FHC',
#    'address': 'Pattiam FHC Cheruvanchery Pattiam',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Chittariparamba',
#    'pincode': 670691,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '244f3214-496a-455d-b9dc-7f20ca8a607f',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604365,
#    'name': 'Irivery CHC',
#    'address': 'Moonuperiya Chakkarakkal Rd Chakkarakkal Kerala',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iriveri',
#    'pincode': 670613,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '97e5e113-37c5-412d-990e-0a12e96257fd',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115141,
#    'name': 'Angel UP School Muzhapilangad',
#    'address': 'Kulam Bazaar Kadavu RoadMuzhappilangad',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iriveri',
#    'pincode': 670662,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '7fcee787-8098-407f-be18-a9bccbba5cb7',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604294,
#    'name': 'Kuthuparamba Taluk Hospital',
#    'address': 'Kuthuparamba Municipal Stadium(Kuthuparamba TH)',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Chittariparamba',
#    'pincode': 670643,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '7e3b9758-bd52-4959-baa5-51c7d4382c45',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604355,
#    'name': 'CHC Mattanur',
#    'address': 'CHC Mattanur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iritty',
#    'pincode': 670702,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '17c1621e-8204-464b-a1f8-21e6d24a99f2',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604365,
#    'name': 'Irivery CHC',
#    'address': 'Moonuperiya Chakkarakkal Rd Chakkarakkal Kerala',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iriveri',
#    'pincode': 670613,
#    'from': '11:30:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '5b1624f9-08d2-4f91-abd1-f9e194d98afc',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['11:30AM-01:30PM', '01:30PM-03:00PM']},
#   {'center_id': 604369,
#    'name': 'Taluk Hospital Payyanur',
#    'address': 'Govt. Boys School Payyanur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pazhayangadi',
#    'pincode': 670307,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '1a6735cf-2fce-4797-b3e9-509375c074a6',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 115480,
#    'name': 'Ramanthali PHC',
#    'address': 'Ramanthali PHC RamanthaliRamanthali P O',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pazhayangadi',
#    'pincode': 670308,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': 'c89884b6-cc39-4a0e-8b6e-9ab7a94839a6',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 115290,
#    'name': 'New Mahe PHC',
#    'address': 'New Mahe PHC  New Mahi Kurichiyil P O',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pinarayi',
#    'pincode': 670102,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '49b9ceb4-8565-4179-bdf3-f2029c37088f',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 115570,
#    'name': 'Peravoor TH',
#    'address': 'Peravoor THQH Peravoor Peravoor P.O.',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Keezhpally',
#    'pincode': 670673,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': 'eff985de-0f6b-4eb0-9cff-7cb838ce7f93',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604361,
#    'name': 'Iritty Taluk Hospital',
#    'address': 'Iritty High School Road Keezhur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iritty',
#    'pincode': 670703,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '2d6f3955-352d-4af9-9173-59cea1a2edb5',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 609163,
#    'name': 'Panniyannur PHC',
#    'address': 'PHC Panniyannur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Panoor',
#    'pincode': 670671,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '55bbfdc6-c80c-435b-b289-b23d7d1914e4',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115076,
#    'name': 'Porora UPHC',
#    'address': 'Porora UPHC Porora  Porora P O',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iritty',
#    'pincode': 670702,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': 'd7557f58-4a40-4869-bcfe-83ac48f83544',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115845,
#    'name': 'Pattuvam FHC',
#    'address': 'FHC PATTUVAM',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Ezhome',
#    'pincode': 670143,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '54adb15d-1069-48ad-8184-c6083816ad1c',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 627785,
#    'name': 'Military Hospital Cannanore',
#    'address': 'Military Hospital Kannur Near Payyambalam Beach Kannur Kerala',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Azhikode',
#    'pincode': 670001,
#    'from': '09:00:00',
#    'to': '18:00:00',
#    'lat': 0,
#    'long': 0,
#    'fee_type': 'Free',
#    'session_id': '2bbc4df8-1830-47ac-8977-71054a124c8c',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-06:00PM']},
#   {'center_id': 115419,
#    'name': 'Chittariparamba PHC',
#    'address': 'PHC Chittariparamba',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Chittariparamba',
#    'pincode': 670650,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '5fa3b7be-de3f-428f-80e0-df7cb1164739',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115523,
#    'name': 'Kankolalapadamba FHC',
#    'address': 'Kankolalapadamba FHC Kankl Alappadamba Mathil P O',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Peringome',
#    'pincode': 670521,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '882f8e97-0d61-42b0-9451-7f26a3187131',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604361,
#    'name': 'Iritty Taluk Hospital',
#    'address': 'Iritty High School Road Keezhur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Iritty',
#    'pincode': 670703,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '7e98b75d-635e-4c48-a0e1-101d2e13cc06',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 646974,
#    'name': 'UPHC Maithanapally',
#    'address': 'UPHC MYTHANAPPALLY THAYYIL PO KANNUR',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Azhikode',
#    'pincode': 670007,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 11,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '4779cc5c-3333-4451-b2e7-dba6825bafbe',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 604344,
#    'name': 'FHC Kadirur',
#    'address': 'FHC Kadirur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pinarayi',
#    'pincode': 670642,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 0,
#    'long': 0,
#    'fee_type': 'Free',
#    'session_id': '54e75ec6-44b7-47f4-800e-94eb3122caba',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 115214,
#    'name': 'Kunnothparamba PHC',
#    'address': 'Kunnothparamba PHC Nillangal Kunnothparamba',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Panoor',
#    'pincode': 670692,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 0,
#    'long': 0,
#    'fee_type': 'Free',
#    'session_id': '305f847f-f784-42c3-9ddb-8031b5a3aa38',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604344,
#    'name': 'FHC Kadirur',
#    'address': 'FHC Kadirur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pinarayi',
#    'pincode': 670642,
#    'from': '12:00:00',
#    'to': '15:00:00',
#    'lat': 0,
#    'long': 0,
#    'fee_type': 'Free',
#    'session_id': '3b6e0db0-a7ce-4fa9-a146-ef9155669ac3',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['12:00PM-02:00PM', '02:00PM-03:00PM']},
#   {'center_id': 115498,
#    'name': 'Alakkad PHC',
#    'address': 'Alakkad PHC Alakkad P O Eriam',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Peringome',
#    'pincode': 670306,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '7c0ff254-fe13-40d4-a9e2-e8c5be6afc35',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']},
#   {'center_id': 604369,
#    'name': 'Taluk Hospital Payyanur',
#    'address': 'Govt. Boys School Payyanur',
#    'state_name': 'Kerala',
#    'district_name': 'Kannur',
#    'block_name': 'Pazhayangadi',
#    'pincode': 670307,
#    'from': '09:00:00',
#    'to': '15:00:00',
#    'lat': 12,
#    'long': 75,
#    'fee_type': 'Free',
#    'session_id': '2f0e7daf-2720-4d99-8a5a-c7bf9ad34ed5',
#    'date': '01-06-2021',
#    'available_capacity_dose1': 0,
#    'available_capacity_dose2': 0,
#    'available_capacity': 0,
#    'fee': '0',
#    'min_age_limit': 18,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-10:00AM',
#     '10:00AM-11:00AM',
#     '11:00AM-12:00PM',
#     '12:00PM-03:00PM']}]}

# %%
pd.DataFrame([[1,2,3]],columns=['onw','jj','gg'])
# Out:
#    onw  jj  gg
# 0    1   2   3

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
st.__version__
# Out:
# '0.81.1'

# %%
requests.__version__
# Out:
# '2.25.1'

# %%
np.__version__
# Out:
# '1.20.1'

# %%
fff=pd.read_csv('cowinkerala.csv')

# %%
list(fff['districts'])
# Out:
# ['Kasaragod',
#  'Thiruvananthapuram',
#  'Kannur',
#  'Kollam',
#  'Wayanad',
#  'Pathanamthitta',
#  'Alappuzha',
#  'Malappuram',
#  'Thrissur',
#  'Kottayam',
#  'Kozhikode',
#  'Idukki',
#  'Ernakulam',
#  'Palakkad']

# %%
pd.DataFrame([{'hi':'nandumm'}])
# Out:
#         hi
# 0  nandumm

# %%
st.__version__
# Out:
# '0.81.1'

# %%
import streamlit as st
